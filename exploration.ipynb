# %%
import pandas as pd
from pprint import pprint
import json

# %%
movies_df = pd.read_csv("Resources/tmdb_5000_movies.csv")

movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# all_genre_names = []
# # Iterate through each row in the DataFrame
# for index, row in movies_df.iterrows():
#     genre_data = json.loads(row['genres'])
#     genre_names = []
#     for genre in genre_data:
#         if "name" in genre:
#             genre_names.append(genre["name"])
#     all_genre_names.append(genre_names)
# # Now, `all_genre_names` is a list of lists containing genre names for each row
# all_genre_names
# Out:
# [['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Fantasy', 'Action', 'Adventure'],
#  ['Animation', 'Family'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Adventure', 'Fantasy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Adventure', 'Fantasy', 'Action', 'Science Fiction'],
#  ['Adventure', 'Action', 'Thriller', 'Crime'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Action', 'Adventure', 'Western'],
#  ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Science Fiction', 'Action', 'Adventure'],
#  ['Adventure', 'Action', 'Fantasy'],
#  ['Action', 'Comedy', 'Science Fiction'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure'],
#  ['Adventure', 'Fantasy'],
#  ['Adventure', 'Fantasy'],
# ...

# %%
all_genre_names = []
# Iterate through each row in the DataFrame
for index, row in movies_df.iterrows():
    genre_data = json.loads(row['genres'])
    genre_names = []
    for genre in genre_data:
        if "name" in genre:
            genre_names.append(genre["name"])
    genre_names_str = ', '.join(genre_names)
    all_genre_names.append(genre_names_str)
all_genre_names
# Out:
# ['Action, Adventure, Fantasy, Science Fiction',
#  'Adventure, Fantasy, Action',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama, Thriller',
#  'Action, Adventure, Science Fiction',
#  'Fantasy, Action, Adventure',
#  'Animation, Family',
#  'Action, Adventure, Science Fiction',
#  'Adventure, Fantasy, Family',
#  'Action, Adventure, Fantasy',
#  'Adventure, Fantasy, Action, Science Fiction',
#  'Adventure, Action, Thriller, Crime',
#  'Adventure, Fantasy, Action',
#  'Action, Adventure, Western',
#  'Action, Adventure, Fantasy, Science Fiction',
#  'Adventure, Family, Fantasy',
#  'Science Fiction, Action, Adventure',
#  'Adventure, Action, Fantasy',
#  'Action, Comedy, Science Fiction',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure',
#  'Adventure, Fantasy',
#  'Adventure, Fantasy',
#  'Adventure, Drama, Action',
#  'Drama, Romance, Thriller',
#  'Adventure, Action, Science Fiction',
# ...

# %%
movies_df["genres"] = all_genre_names

for i
movies_df["genres"][0].split(', ')
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
all_keywords = []
# Iterate through each row in the DataFrame
for index, row in movies_df.iterrows():
    keyword_data = json.loads(row['keywords'])
    keyword_names = []
    for keyword in keyword_data:
        if "name" in keyword:
            keyword_names.append(keyword["name"])
    keyword_names_str = ', '.join(keyword_names)
    all_keywords.append(keyword_names_str)
all_keywords
# Out:
# ['culture clash, future, space war, space colony, society, space travel, futuristic, romance, space, alien, tribe, alien planet, cgi, marine, soldier, battle, love affair, anti war, power relations, mind and soul, 3d',
#  "ocean, drug abuse, exotic island, east india trading company, love of one's life, traitor, shipwreck, strong woman, ship, alliance, calypso, afterlife, fighter, pirate, swashbuckler, aftercreditsstinger",
#  'spy, based on novel, secret agent, sequel, mi6, british secret service, united kingdom',
#  'dc comics, crime fighter, terrorist, secret identity, burglar, hostage drama, time bomb, gotham city, vigilante, cover-up, superhero, villainess, tragic hero, terrorism, destruction, catwoman, cat burglar, imax, flood, criminal underworld, batman',
#  'based on novel, mars, medallion, space travel, princess, alien, steampunk, martian, escape, edgar rice burroughs, alien race, superhuman strength, mars civilization, sword and planet, 19th century, 3d',
# ...

# %%
movies_df["keywords"] = all_keywords
movies_df["keywords"][0]
# Out:
# 'culture clash, future, space war, space colony, society, space travel, futuristic, romance, space, alien, tribe, alien planet, cgi, marine, soldier, battle, love affair, anti war, power relations, mind and soul, 3d'
